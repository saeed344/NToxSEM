# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 7.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# #peptides features readings

# %%
import pandas as pd
import numpy as np

# path = '/content/drive/MyDrive/Watashara_Projects/neurotoxic/'
path = 'D:/A Max-project/10-NTxPred/neurotoxic/'

# Load Training Features

feat11 = pd.read_csv(path + 'features/peptides/BLOSUM62_CV.csv', index_col=0)
feat12 = pd.read_csv(path + 'features/peptides/TRN_esm2_640_Train.csv', header=None)
feat13 = pd.read_csv(path + 'features/peptides/TRN_prot_t5_xl_bfd.csv', index_col=0)
feat14 = pd.read_csv(path + 'features/peptides/TRN_prot_t5_xl_uniref50.csv', index_col=0)
feat15 = pd.read_csv(path + 'features/peptides/TNR_1Ngram_Fasttext.csv')
feat16 = pd.read_csv(path + 'features/peptides/TRN_FEGS.csv')
feat17 = pd.read_csv(path + 'features/peptides/TRN_iBitter_features.csv', index_col=0)
feat18 = pd.read_csv(path + 'features/peptides/AAC_CV.csv', index_col=0)
feat19 = pd.read_csv(path + 'features/peptides/DPC_CV.csv', index_col=0)
feat20 = pd.read_csv(path + 'features/peptides/TPC_CV.csv', index_col=0)
feat21 = pd.read_csv(path + 'features/peptides/TRN_BioBERT.csv', index_col=0)
feat22 = pd.read_csv(path + 'features/peptides/AAINDEX_CV.csv', index_col=0)
feat23 = pd.read_csv(path + 'features/peptides/TRN_bert_features.csv', index_col=0)
feat24 = pd.read_csv(path + 'features/peptides/PAAC_CV.csv', index_col=0)
feat23 = pd.read_csv(path + 'features/peptides/TNR_RECM_DCT.csv', header=None)
feat24 = pd.read_csv(path + 'features/peptides/TNR_esm2_320.csv', header=None)
feat25 = pd.read_csv(path + 'features/peptides/TRN_RECM_CLBP_features.csv', header=None)
feat26 = pd.read_csv(path + 'features/peptides/TRN_esm2_480.csv', header=None)

feat27 = pd.read_csv(path + 'features/peptides/TRN_esm2_1280_Train.csv', header=None)

# Combine Training Features
allfeat_train = np.hstack((feat1, feat2, feat3,feat4,feat5,feat6, feat7, feat8,feat9, feat10,
                           feat11, feat12, feat13, feat14, feat15, feat16, feat17,feat18,feat19,feat20,feat21,feat22,feat23,feat24))
# feat20,feat21, feat24, feat25, feat26, feat27, feat28))

# Labels for Training
label1 = np.ones((701, 1))
label2 = np.zeros((702, 1))
y = np.vstack((label1, label2))

# train_label = pd.read_csv(path + 'peptides/trainingntx.csv')

# # X = train_label.iloc[:, :-1].values
# y = train_label.iloc[:, -1].values
print(np.shape(y))

print("Train features shape:", allfeat_train.shape)
# print("Test features shape:", allfeat_test.shape)
print("Train labels shape:", y.shape)
# print("Test labels shape:", yt.shape)
# Out:
# (1403, 1)
# Train features shape: (1403, 15260)
# Train labels shape: (1403, 1)

# %%
path = 'D:/A Max-project/10-NTxPred/neurotoxic/'
# Load Independent Test Features (same order)

feat11 = pd.read_csv(path + 'features/peptides/BLOSUM62_IND.csv', index_col=0)
feat12 = pd.read_csv(path + 'features/peptides/IND_esm2_640_Train.csv', header=None)
feat13 = pd.read_csv(path + 'features/peptides/IND_prot_t5_xl_bfd.csv', index_col=0)
feat14 = pd.read_csv(path + 'features/peptides/IND_prot_t5_xl_uniref50.csv', index_col=0)
feat15 = pd.read_csv(path + 'features/peptides/IND_1Ngram_Fasttext.csv')
feat16= pd.read_csv(path + 'features/peptides/IND_FEGS.csv')
feat17 = pd.read_csv(path + 'features/peptides/IND_iBitter_features.csv', index_col=0)
feat18 = pd.read_csv(path + 'features/peptides/AAC_IND.csv', index_col=0)
feat19 = pd.read_csv(path + 'features/peptides/DPC_IND.csv', index_col=0)
feat20 = pd.read_csv(path + 'features/peptides/TPC_IND.csv', index_col=0)
feat21 = pd.read_csv(path + 'features/peptides/IND_BioBERT.csv', index_col=0)
feat22= pd.read_csv(path + 'features/peptides/AAINDEX_IND.csv', index_col=0)
feat23= pd.read_csv(path + 'features/peptides/IND_bert_features.csv', index_col=0)
feat24 = pd.read_csv(path + 'features/peptides/PAAC_IND.csv', index_col=0)
# feat21 = pd.read_csv(path + 'features/peptides/IND_RECM_DCT.csv', header=None)
# feat22 = pd.read_csv(path + 'features/peptides/IND_esm2_320.csv', header=None)
# feat7 = pd.read_csv(path + 'features/peptides/IND_RECM_CLBP_features.csv', header=None)
# feat8 = pd.read_csv(path + 'features/peptides/IND_esm2_480.csv', header=None)
# feat18 = pd.read_csv(path + 'features/peptides/IND_esm2_1280_Train.csv', header=None)


# Combine Independent Test Features
allfeat_test = np.hstack((feat1, feat2, feat3,feat4,feat5,feat6, feat7, feat8,feat9, feat10,
                           feat11, feat12, feat13, feat14, feat15, feat16, feat17,feat18,feat19,feat20,feat21,feat22,feat23,feat24))
# feat3, feat4, feat7, feat8,feat17, feat18,




#IND_BioBERT,IND_prot_t5_xl_bfd,IND_prot_t5_xl_uniref50,IND_bert,
# Labels for testing
# test_label = pd.read_csv(path + 'peptides/testingntx.csv')

# X = test_label.iloc[:, :-1].values
# yt = test_label.iloc[:, -1].values
# print(np.shape(yt))


labela = np.ones((176, 1))
labelb = np.zeros((175, 1))
yt = np.vstack((labela, labelb))

# Check shapes
print("Test features shape:", allfeat_test.shape)
print("Test labels shape:", yt.shape)
# Out:
# Test features shape: (351, 15260)
# Test labels shape: (351, 1)

# %%
import pandas as pd

# path = '/content/drive/MyDrive/Watashara_Projects/neurotoxic/'
path = 'D:/A Max-project/10-NTxPred/neurotoxic/'

# Helper function to load and print shape
def print_shape(name, filepath, **kwargs):
    df = pd.read_csv(filepath, **kwargs)
    print(f"{name} shape: {df.shape}")
    return df

print("------ Train Feature Shapes ------")
print_shape('Train_AAC', path + 'features/combined/AAC_CV.csv', index_col=0)
print_shape('Train_DPC', path + 'features/combined/DPC_CV.csv', index_col=0)
print_shape('Train_TPC', path + 'features/combined/TPC_CV.csv', index_col=0)
print_shape('Train_RECM_DCT', path + 'features/combined/TRN_RECM_DCT.csv', header=None)
print_shape('Train_esm2_320', path + 'features/combined/TRN_esm2_320.csv', header=None)
print_shape('Train_BioBERT', path + 'features/combined/TRN_BioBERT.csv', index_col=0)
print_shape('Train_AAINDEX', path + 'features/combined/AAINDEX_CV.csv', index_col=0)
print_shape('Train_RECM_CLBP', path + 'features/combined/TRN_RECM_CLBP_features.csv', header=None)
print_shape('Train_esm2_480', path + 'features/combined/TRN_esm2_480.csv', header=None)
print_shape('Train_bert', path + 'features/combined/TRN_bert_features.csv', index_col=0)
print_shape('Train_PAAC', path + 'features/combined/PAAC_CV.csv', index_col=0)
print_shape('Train_BLOSUM62', path + 'features/combined/BLOSUM62_CV.csv', index_col=0)
print_shape('Train_prot_t5_bfd', path + 'features/combined/TRN_prot_t5_xl_bfd.csv', index_col=0)
print_shape('Train_prot_t5_uniref50', path + 'features/combined/TRN_prot_t5_xl_uniref50.csv', index_col=0)
print_shape('Train_DCGR', path + 'features/combined/TNR_DCGR.csv')
print_shape('Train_FEGS', path + 'features/combined/TRN_FEGS.csv')
print_shape('Train_iBitter', path + 'features/combined/TRN_iBitter_features.csv', index_col=0)
print_shape('Train_esm2_640', path + 'features/combined/TRN_esm2_640.csv', header=None)
print_shape('Train_esm2_1280', path + 'features/combined/TRN_esm2_1280_Train.csv', header=None)

print("\n------ Test Feature Shapes ------")
print_shape('Test_AAC', path + 'features/combined/AAC_IND.csv', index_col=0)
print_shape('Test_DPC', path + 'features/combined/DPC_IND.csv', index_col=0)
print_shape('Test_TPC', path + 'features/combined/TPC_IND.csv', index_col=0)
print_shape('Test_RECM_DCT', path + 'features/combined/IND_RECM_DCT.csv', header=None)
print_shape('Test_esm2_320', path + 'features/combined/IND_esm2_320.csv', header=None)
print_shape('Test_BioBERT', path + 'features/combined/IND_BioBERT.csv', index_col=0)
print_shape('Test_AAINDEX', path + 'features/combined/AAINDEX_IND.csv', index_col=0)
print_shape('Test_RECM_CLBP', path + 'features/combined/IND_RECM_CLBP_features.csv', header=None)
print_shape('Test_esm2_480', path + 'features/combined/IND_esm2_480.csv', header=None)
print_shape('Test_bert', path + 'features/combined/IND_bert_features.csv', index_col=0)
print_shape('Test_PAAC', path + 'features/combined/PAAC_IND.csv', index_col=0)
print_shape('Test_BLOSUM62', path + 'features/combined/BLOSUM62_IND.csv', index_col=0)
print_shape('Test_prot_t5_bfd', path + 'features/combined/IND_prot_t5_xl_bfd.csv', index_col=0)
print_shape('Test_prot_t5_uniref50', path + 'features/combined/IND_prot_t5_xl_uniref50.csv', index_col=0)
print_shape('Test_DCGR', path + 'features/combined/IND_DCGR.csv')
print_shape('Test_FEGS', path + 'features/combined/IND_FEGS.csv')
print_shape('Test_iBitter', path + 'features/combined/IND_iBitter_features.csv', index_col=0)
print_shape('Test_esm2_640', path + 'features/combined/IND_esm2_640.csv', header=None)
print_shape('Test_esm2_1280', path + 'features/combined/IND_esm2_1280_Train.csv', header=None)
# Out:
# ------ Train Feature Shapes ------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18876\3014758695.py in <module>
#      10
#      11 print("------ Train Feature Shapes ------")
# ---> 12 print_shape('Train_AAC', path + 'features/combined/AAC_CV.csv', index_col=0)
#      13 print_shape('Train_DPC', path + 'features/combined/DPC_CV.csv', index_col=0)
#      14 print_shape('Train_TPC', path + 'features/combined/TPC_CV.csv', index_col=0)
#
# ~\AppData\Local\Temp\ipykernel_18876\3014758695.py in print_shape(name, filepath, **kwargs)
#       5 # Helper function to load and print shape
#       6 def print_shape(name, filepath, **kwargs):
# ----> 7     df = pd.read_csv(filepath, **kwargs)
#       8     print(f"{name} shape: {df.shape}")
#       9     return df
#
# ...

# %%
import pandas as pd
import numpy as np

path = 'D:/A Max-project/10-NTxPred/neurotoxic/'

# Load CV features
feat1 = pd.read_csv(path + 'features/peptides/AAC_CV.csv', index_col=0)
feat2 = pd.read_csv(path + 'features/peptides/DPC_CV.csv', index_col=0)
feat3 = pd.read_csv(path + 'features/peptides/TPC_CV.csv', index_col=0)
feat4 = pd.read_csv(path + 'features/peptides/TNR_RECM_DCT.csv', header=None)
feat5 = pd.read_csv(path + 'features/peptides/TNR_esm2_320.csv', header=None)
feat6 = pd.read_csv(path + 'features/peptides/TRN_BioBERT.csv', index_col=0)
feat7 = pd.read_csv(path + 'features/peptides/AAINDEX_CV.csv', index_col=0)
feat8 = pd.read_csv(path + 'features/peptides/TRN_RECM_CLBP_features.csv', header=None)
feat9= pd.read_csv(path + 'features/peptides/TRN_bert_features.csv', index_col=0)
feat10 = pd.read_csv(path + 'features/peptides/TRN_esm2_480.csv', header=None)
feat11 = pd.read_csv(path + 'features/peptides/PAAC_CV.csv', index_col=0)
feat12 = pd.read_csv(path + 'features/peptides/BLOSUM62_CV.csv', index_col=0)
feat13 = pd.read_csv(path + 'features/peptides/TRN_prot_t5_xl_bfd.csv', index_col=0)
feat14 = pd.read_csv(path + 'features/peptides/TRN_prot_t5_xl_uniref50.csv', index_col=0)
# feat15 = pd.read_csv(path + 'features/peptides/ExPAAC_CV.csv', index_col=0)
# feat15 = pd.read_csv(path + 'features/peptides/TRN_DCGR.csv')
feat15 = pd.read_csv(path + 'features/peptides/TRN_FEGS.csv')
feat16 = pd.read_csv(path + 'features/peptides/TRN_esm2_640_Train.csv', header=None)
feat17 = pd.read_csv(path + 'features/peptides/TRN_esm2_1280_Train.csv', header=None)
feat18 = pd.read_csv(path + 'features/peptides/TRN_iBitter_features.csv', index_col=0)


# Combine CV features
all_train_features = np.column_stack(( feat1, feat2, feat3, feat4, feat5,
    feat6, feat7, feat8,feat9, feat10, feat11,feat12, feat13,feat14,feat15,feat16,feat17,feat18))


#feat2,feat3,feat7,feat11,feat12,iBitter_TRN,,
# Labels for training
label1 = np.ones((701, 1))
label2 = np.zeros((702, 1))
y = np.vstack((label1, label2))


# Load IND features
feat1 = pd.read_csv(path + 'features/peptides/AAC_IND.csv', index_col=0)
feat2 = pd.read_csv(path + 'features/peptides/DPC_IND.csv', index_col=0)
feat3 = pd.read_csv(path + 'features/peptides/TPC_IND.csv', index_col=0)
feat4 = pd.read_csv(path + 'features/peptides/IND_RECM_DCT.csv', header=None)
feat5 = pd.read_csv(path + 'features/peptides/IND_esm2_320.csv', header=None)
feat6 = pd.read_csv(path + 'features/peptides/IND_BioBERT.csv', index_col=0)
feat7 = pd.read_csv(path + 'features/peptides/AAINDEX_IND.csv', index_col=0)
feat8 = pd.read_csv(path + 'features/peptides/IND_RECM_CLBP_features.csv', header=None)
feat9 = pd.read_csv(path + 'features/peptides/IND_bert_features.csv', index_col=0)
feat10 = pd.read_csv(path + 'features/peptides/IND_esm2_480.csv', header=None)
feat11 = pd.read_csv(path + 'features/peptides/PAAC_IND.csv', index_col=0)
feat12 = pd.read_csv(path + 'features/peptides/BLOSUM62_IND.csv', index_col=0)
feat13 = pd.read_csv(path + 'features/peptides/IND_prot_t5_xl_bfd.csv', index_col=0)
feat14 = pd.read_csv(path + 'features/peptides/IND_prot_t5_xl_uniref50.csv', index_col=0)
# feat15 = pd.read_csv(path + 'features/peptides/ExPAAC_IND.csv', index_col=0)
# feat15 = pd.read_csv(path + 'features/peptides/IND_DCGR.csv')
feat15 = pd.read_csv(path + 'features/peptides/IND_FEGS.csv')
feat16 = pd.read_csv(path + 'features/peptides/IND_esm2_640_Train.csv', header=None)
feat17 = pd.read_csv(path + 'features/peptides/IND_esm2_1280_Train.csv', header=None)
feat18 = pd.read_csv(path + 'features/peptides/IND_iBitter_features.csv', index_col=0)


# Combine IND features
all_test_features = np.column_stack(( feat1, feat2, feat3, feat4, feat5,
    feat6, feat7, feat8,feat9, feat10, feat11,feat12, feat13,feat14,feat15,feat16,feat17,feat18))



#feat2,feat3,feat7,feat11,feat12
# Labels for testing
labela = np.ones((176, 1))
labelb = np.zeros((175, 1))
yt = np.vstack((labela, labelb))

# Check shapes
print("Train features shape:", all_train_features.shape)
print("Test features shape:", all_test_features.shape)
print("Train labels shape:", all_test_features.shape)
print("Test labels shape:", yt.shape)


# === Combine all features and labels ===
X_all = np.vstack((all_train_features, all_test_features))
y_all = np.vstack((y, yt))

print("Combined features shape:", X_all.shape)
print("Combined labels shape:", y_all.shape)
from sklearn.model_selection import train_test_split
X, Xt, y, yt = train_test_split(X_all, y_all, test_size = 0.25, random_state = True)
# Out:
# Train features shape: (1403, 16715)
# Test features shape: (351, 16715)
# Train labels shape: (351, 16715)
# Test labels shape: (351, 1)
# Combined features shape: (1754, 16715)
# Combined labels shape: (1754, 1)

# %%
import os
import re, os, sys
from collections import Counter
import math
import numpy as np
import re

import pandas as pd

# %%
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
from catboost import CatBoostClassifier
from sklearn.linear_model import ElasticNet
from sklearn.metrics import roc_auc_score
import lightgbm as lgb


def cv(clf, X, y, nr_fold):
    ix = []
    for i in range(0, len(y)):
        ix.append(i)
    ix = np.array(ix)

    allACC = []
    allSENS = []
    allSPEC = []
    allMCC = []
    allAUC = []
    for j in range(0, nr_fold):
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = X[train_ix], X[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
        clf.fit(train_X, train_y)
        p = clf.predict(test_X)
        pr = clf.predict_proba(test_X)[:, 1]
        TP = 0
        FP = 0
        TN = 0
        FN = 0
        for i in range(0, len(test_y)):
            if test_y[i] == 0 and p[i] == 0:
                TP += 1
            elif test_y[i] == 0 and p[i] == 1:
                FN += 1
            elif test_y[i] == 1 and p[i] == 0:
                FP += 1
            elif test_y[i] == 1 and p[i] == 1:
                TN += 1
        ACC = (TP + TN) / (TP + FP + TN + FN)
        SENS = TP / (TP + FN)
        SPEC = TN / (TN + FP)
        det = math.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))
        if (det == 0):
            MCC = 0
        else:
            MCC = ((TP * TN) - (FP * FN)) / det
        AUC = roc_auc_score(test_y, pr)
        allACC.append(ACC)
        allSENS.append(SENS)
        allSPEC.append(SPEC)
        allMCC.append(MCC)
        allAUC.append(AUC)
    return np.mean(allACC), np.mean(allSENS), np.mean(allSPEC), np.mean(allMCC), np.mean(allAUC)


def test(clf, X, y, Xt, yt):
    train_X, test_X = X, Xt
    train_y, test_y = y, yt
    clf.fit(train_X, train_y)
    p = clf.predict(test_X)
    pr = clf.predict_proba(test_X)[:, 1]
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    for i in range(0, len(test_y)):
        if test_y[i] == 0 and p[i] == 0:
            TP += 1
        elif test_y[i] == 0 and p[i] == 1:
            FN += 1
        elif test_y[i] == 1 and p[i] == 0:
            FP += 1
        elif test_y[i] == 1 and p[i] == 1:
            TN += 1
    ACC = (TP + TN) / (TP + FP + TN + FN)
    SENS = TP / (TP + FN)
    SPEC = TN / (TN + FP)
    det = math.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))
    if (det == 0):
        MCC = 0
    else:
        MCC = ((TP * TN) - (FP * FN)) / det
    AUC = roc_auc_score(test_y, pr)

    def fcount(string, substr):
        count = 0
        pos = 0
        while (True):
            pos = string.find(substr, pos)
            if pos > -1:
                count = count + 1
                pos += 1
            else:
                break
        return count

    return ACC, SENS, SPEC, MCC, AUC



import random,os
numdesc = 16
random.seed(0)
folder='meta_stacking_peptide_combined'

if not os.path.exists(path + (f'Results/{folder}/')):
    os.makedirs(path + f'Results/{folder}/')
f = []
before = 0
for i in range(numdesc):
    after = before + eval('feat%d.shape[1]' % (i))
    f.append(list(range(before, after)))
    before = after

# X = all_train_features
# labels = pd.read_csv('train_data_features/labels.csv')

# # Convert 'active' to 1 and 'inactive' to 03
# labels['Class'] = labels['Class'].map({'active': 1, 'inactive': 0})
# y = labels['Class'].values

ix = []
for i in range(0, len(y)):
    ix.append(i)
ix = np.array(ix)
nr_fold = 10
featx = []
Cfeat=[]

for i in range(numdesc):
#RF
    from sklearn.ensemble import RandomForestClassifier
    feat = np.zeros((len(X),), dtype=float)
    Cfeat = np.zeros((len(X),), dtype=float)
    for j in range(0, nr_fold):
        Xs = X[:, f[i]]
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = Xs[train_ix], Xs[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
        clf = RandomForestClassifier(n_estimators=500, random_state=0)
        clf.fit(train_X, train_y)
        pr = clf.predict_proba(test_X)[:, 0]
        pr_c = clf.predict(test_X)
        feat[test_ix] = pr
        Cfeat[test_ix] = pr_c
    feat = np.reshape(feat, (len(X), 1))
    Cfeat = np.reshape(Cfeat, (len(X), 1))
    if (i == 0):
        featx = feat
        Cfeatx = Cfeat
    else:
        featx = np.concatenate((featx, feat), axis=1)
        Cfeatx = np.concatenate((Cfeatx, Cfeat), axis=1)

#ET
    from sklearn.ensemble import ExtraTreesClassifier
    feat = np.zeros((len(X),),dtype=float)
    Cfeat = np.zeros((len(X),), dtype=float)
    for j in range(0, nr_fold):
        Xs = X[:,f[i]]
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = Xs[train_ix], Xs[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
        clf = ExtraTreesClassifier(n_estimators=500, random_state=0)
        clf.fit(train_X, train_y)
        pr = clf.predict_proba(test_X)[:,0]
        pr_c = clf.predict(test_X)
        feat[test_ix] = pr
        Cfeat[test_ix] = pr_c
    feat = np.reshape(feat,(len(X),1))
    Cfeat = np.reshape(Cfeat, (len(X), 1))
    featx = np.concatenate((featx,feat),axis=1)
    Cfeatx = np.concatenate((Cfeatx, Cfeat), axis=1)
#SVM
    from sklearn.svm import SVC
    feat = np.zeros((len(X),),dtype=float)
    Cfeat = np.zeros((len(X),), dtype=float)
    for j in range(0, nr_fold):
        Xs = X[:,f[i]]
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = Xs[train_ix], Xs[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
        clf = SVC(probability=True, random_state=0)
        clf.fit(train_X, train_y)
        pr = clf.predict_proba(test_X)[:,0]
        pr_c = clf.predict(test_X)
        feat[test_ix] = pr
        Cfeat[test_ix] = pr_c
    feat = np.reshape(feat,(len(X),1))
    Cfeat = np.reshape(Cfeat, (len(X), 1))
    featx = np.concatenate((featx,feat),axis=1)
    Cfeatx = np.concatenate((Cfeatx, Cfeat), axis=1)

#LGB
    from lightgbm import LGBMClassifier

    feat = np.zeros((len(X),),dtype=float)
    Cfeat = np.zeros((len(X),), dtype=float)
    for j in range(0, nr_fold):
        Xs = X[:,f[i]]
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = Xs[train_ix], Xs[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
        clf = LGBMClassifier()
        clf.fit(train_X, train_y)
        pr = clf.predict_proba(test_X)[:,0]
        pr_c = clf.predict(test_X)
        feat[test_ix] = pr
        Cfeat[test_ix] = pr_c
    feat = np.reshape(feat,(len(X),1))
    Cfeat = np.reshape(Cfeat, (len(X), 1))
    featx = np.concatenate((featx,feat),axis=1)
    Cfeatx = np.concatenate((Cfeatx, Cfeat), axis=1)

#LR
    from sklearn.linear_model import LogisticRegression
    feat = np.zeros((len(X),),dtype=float)
    Cfeat = np.zeros((len(X),), dtype=float)
    for j in range(0, nr_fold):
        Xs = X[:,f[i]]
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = Xs[train_ix], Xs[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
        clf = LogisticRegression(random_state=0, max_iter=5000)
        clf.fit(train_X, train_y)
        pr = clf.predict_proba(test_X)[:,0]
        pr_c = clf.predict(test_X)
        feat[test_ix] = pr
        Cfeat[test_ix] = pr_c
    feat = np.reshape(feat,(len(X),1))
    Cfeat = np.reshape(Cfeat, (len(X), 1))
    featx = np.concatenate((featx,feat),axis=1)
    Cfeatx = np.concatenate((Cfeatx, Cfeat), axis=1)
    from xgboost import XGBClassifier
#XGB
    feat = np.zeros((len(X),), dtype=float)
    Cfeat = np.zeros((len(X),), dtype=float)
    for j in range(0, nr_fold):
        Xs = X[:, f[i]]
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = Xs[train_ix], Xs[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
        clf = XGBClassifier()
        clf.fit(train_X, train_y)
        pr = clf.predict_proba(test_X)[:, 0]
        pr_c = clf.predict(test_X)
        feat[test_ix] = pr
        Cfeat[test_ix] = pr_c
    feat = np.reshape(feat, (len(X), 1))
    Cfeat = np.reshape(Cfeat, (len(X), 1))
    featx = np.concatenate((featx, feat), axis=1)
    Cfeatx = np.concatenate((Cfeatx, Cfeat), axis=1)
    from sklearn.neighbors import KNeighborsClassifier
    feat = np.zeros((len(X),), dtype=float)
    Cfeat = np.zeros((len(X),), dtype=float)
    for j in range(0, nr_fold):
        Xs = X[:, f[i]]
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = Xs[train_ix], Xs[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
#KNN
        clf = KNeighborsClassifier(weights="distance",algorithm="auto")
        clf.fit(train_X, train_y)
        pr = clf.predict_proba(test_X)[:, 0]
        pr_c = clf.predict(test_X)
        feat[test_ix] = pr
        Cfeat[test_ix] = pr_c
    feat = np.reshape(feat, (len(X), 1))
    Cfeat = np.reshape(Cfeat, (len(X), 1))
    featx = np.concatenate((featx, feat), axis=1)
    Cfeatx = np.concatenate((Cfeatx, Cfeat), axis=1)
#CatBoost
    # from PLS import PLS
    feat = np.zeros((len(X),), dtype=float)
    Cfeat = np.zeros((len(X),), dtype=float)
    for j in range(0, nr_fold):
        Xs = X[:, f[i]]
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = Xs[train_ix], Xs[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
        clf = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=6, verbose=0)
        clf.fit(train_X, train_y)
        pr = clf.predict_proba(test_X)[:, 0]
        pr_c = clf.predict(test_X)
        feat[test_ix] = pr
        Cfeat[test_ix] = pr_c
    feat = np.reshape(feat, (len(X), 1))
    Cfeat = np.reshape(Cfeat, (len(X), 1))
    featx = np.concatenate((featx, feat), axis=1)
    Cfeatx = np.concatenate((Cfeatx, Cfeat), axis=1)

#MLP
    from sklearn.neural_network import MLPClassifier
    feat = np.zeros((len(X),),dtype=float)
    Cfeat = np.zeros((len(X),), dtype=float)
    for j in range(0, nr_fold):
        Xs = X[:,f[i]]
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = Xs[train_ix], Xs[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
        clf = MLPClassifier(random_state=0, max_iter=5000)
        clf.fit(train_X, train_y)
        pr = clf.predict_proba(test_X)[:,0]
        feat[test_ix] = pr
    feat = np.reshape(feat,(len(X),1))
    Cfeat = np.reshape(Cfeat, (len(X), 1))
    featx = np.concatenate((featx,feat),axis=1)
    Cfeatx = np.concatenate((Cfeatx, Cfeat), axis=1)
#Descion Tree
    from sklearn.tree import DecisionTreeClassifier
    feat = np.zeros((len(X),),dtype=float)
    Cfeat = np.zeros((len(X),), dtype=float)
    for j in range(0, nr_fold):
        Xs = X[:,f[i]]
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = Xs[train_ix], Xs[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
        clf = DecisionTreeClassifier()
        clf.fit(train_X, train_y)
        pr = clf.predict_proba(test_X)[:,0]
        feat[test_ix] = pr
    feat = np.reshape(feat,(len(X),1))
    Cfeat = np.reshape(Cfeat, (len(X), 1))
    featx = np.concatenate((featx,feat),axis=1)
    Cfeatx = np.concatenate((Cfeatx, Cfeat), axis=1)
#NB
    from sklearn.naive_bayes import GaussianNB
    feat = np.zeros((len(X),),dtype=float)
    Cfeat = np.zeros((len(X),), dtype=float)
    for j in range(0, nr_fold):
        Xs = X[:,f[i]]
        train_ix = ((ix % nr_fold) != j)
        test_ix = ((ix % nr_fold) == j)
        train_X, test_X = Xs[train_ix], Xs[test_ix]
        train_y, test_y = y[train_ix], y[test_ix]
        clf = GaussianNB()
        clf.fit(train_X, train_y)
        pr = clf.predict_proba(test_X)[:,0]
        feat[test_ix] = pr
    feat = np.reshape(feat,(len(X),1))
    Cfeat = np.reshape(Cfeat, (len(X), 1))
    featx = np.concatenate((featx,feat),axis=1)
    Cfeatx = np.concatenate((Cfeatx, Cfeat), axis=1)
# Out:
# c:\Users\My PC\anaconda3\envs\saeed\lib\site-packages\ipykernel_launcher.py:154: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# c:\Users\My PC\anaconda3\envs\saeed\lib\site-packages\ipykernel_launcher.py:154: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# c:\Users\My PC\anaconda3\envs\saeed\lib\site-packages\ipykernel_launcher.py:154: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# c:\Users\My PC\anaconda3\envs\saeed\lib\site-packages\ipykernel_launcher.py:154: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...
